# %%
# Installazione del package Ultralytics
# !pip install ultralytics


from google.colab import drive

# Monta Google Drive su /content/drive
#drive.mount('/content/drive')
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.59-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.59-py3-none-any.whl (906 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 21.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.59 ultralytics-thop-2.0.13

# %% [markdown]
# ### GENERAZIONE DATASET

# %%
import cv2
import os
import xml.etree.ElementTree as ET

video_path = ['/content/ID-1.avi', '/content/ID-2.avi','/content/ID-3.avi','/content/ID-4.avi' ]  # Percorso del video
images_dir = 'drive/MyDrive/dataset/images/'  # Directory per salvare i fotogrammi
os.makedirs(images_dir, exist_ok=True)



for i in range(len(video_path)):

  # Caricamento del video
  cap = cv2.VideoCapture(video_path[i])
  frame_count = 0


  while cap.isOpened():
      ret, frame = cap.read()
      if not ret:
          break  # Fine del video
      # Salva il fotogramma come immagine
      frame_filename = os.path.join(images_dir, f'{i}_{frame_count:05d}.jpg')
      cv2.imwrite(frame_filename, frame)
      frame_count += 1

  cap.release()
#FINE CARICAMENTO IMMAGINI


xml_path = ['/content/ID-1.xml', '/content/ID-2.xml', '/content/ID-3.xml', '/content/ID-4.xml']  # Percorso del file XML
labels_dir = 'drive/MyDrive/dataset/labels/'      # Directory per i file YOLO
os.makedirs(labels_dir, exist_ok=True)


box_width = 25
box_height = 25



# Funzione per normalizzare le coordinate
def normalize_coordinates(x, y, img_width, img_height, box_width, box_height):
    x_center = x / img_width
    y_center = y / img_height
    width_norm = box_width / img_width
    height_norm = box_height / img_height
    return x_center, y_center, width_norm, height_norm

for i in range (len(xml_path)):

    # Carica il file XML
    tree = ET.parse(xml_path[i])
    root = tree.getroot()

    # Dimensioni originali dell'immagine
    original_width = int(root.find(".//original_size/width").text)
    original_height = int(root.find(".//original_size/height").text)

    # Processa i punti per ogni frame
    for track in root.findall('track'):
        for points in track.findall('points'):
            frame_id = points.get('frame')  # ID del frame
            outside = int(points.get('outside'))
            attributes = {attr.attrib["name"]: attr.text for attr in points.findall("attribute")}
            used_in_game = int(attributes.get("used_in_game", 1))  # Predefinito 1 se non specificato

            # Ignora i frame con outside=1 o used_in_game=0
            if outside == 1 or used_in_game == 0:
                continue

            coordinates = points.get('points').split(',')  # Estrai le coordinate
            x, y = float(coordinates[0]), float(coordinates[1])

            # Normalizza le coordinate per YOLO
            x_center, y_center, w, h = normalize_coordinates(
                x, y, original_width, original_height, box_width, box_height
            )

            # Scrivi il file YOLO per il frame
            yolo_filename = os.path.join(labels_dir, f'{i}_{int(frame_id):05d}.txt')
            with open(yolo_filename, 'w') as f:
                f.write(f"0 {x_center:.6f} {y_center:.6f} {w:.6f} {h:.6f}\n")  # Class ID = 0




#ELIMINAZIONE IMMAGINI NON ANNOTATE

# Ottieni i nomi base (senza estensione) dei file .txt nella directory labels
label_files = {os.path.splitext(f)[0] for f in os.listdir(labels_dir) if f.endswith('.txt')}


# Itera su tutti i file nella directory delle immagini
for image_file  in os.listdir(images_dir):
    image_base, ext = os.path.splitext(image_file)
    if image_base not in label_files:
        image_path = os.path.join(images_dir, image_file)
        if os.path.isfile(image_path):  # Verifica che sia un file
            os.remove(image_path)

# %% [markdown]
# ### TRAINING MODELLO

# %%
from ultralytics import YOLO
# !mv /content/training_yolo.yaml /content/drive/MyDrive/dataset/
import torch
torch.cuda.empty_cache()


# Carica il modello preaddestrato (es. yolov8s, yolov8m, etc.)
model = YOLO('yolov8m.pt')  # Puoi scegliere anche altre versioni (yolov8n.pt, yolov8m.pt, etc.)

model.train(
    data='/content/drive/MyDrive/dataset/training_yolo.yaml',  # Percorso del file YAML
    epochs=50,                    # Numero di epoche
    batch=16,                     # Dimensione del batch
    imgsz=800,
    patience=5,
    project='/content/drive/MyDrive/yolov8_project',  # Directory per i risultati
    name='sports_ball_model',     # Nome della sessione di training
    save=True,                    # Salva il modello al termine
)

# %% [markdown]
# ### FUNZIONI PER POST-PROCESSING CON TECNICA DI EMBEDDING

# %%
import torch
import torchvision.transforms as transforms
from torchvision.models import efficientnet_b0
from PIL import Image
from sklearn.metrics.pairwise import cosine_similarity
import math
import os

# Definizione modello per embedding, con rimozione della testa
model_emb = efficientnet_b0(pretrained=True)
model_emb = torch.nn.Sequential(*list(model_emb.children())[:-1])
model_emb.eval()  # Modalità di valutazione (disabilita dropout, batchnorm)


# Preprocessamento per le immagini
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),  # EfficientNet richiede immagini 224x224
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def extract_embedding(image_path):


    image = Image.open(image_path).convert('RGB')  # Converte in RGB
    input_tensor = preprocess(image).unsqueeze(0)  # Aggiunge dimensione batch

    # Passa l'immagine attraverso il modello per ottenere le feature

    with torch.no_grad():  # Disabilita il calcolo dei gradienti
        features = model_emb(input_tensor)
    # Appiattisce il tensor (da [1, 1280, 1, 1] a [1, 1280])
    embedding = features.flatten(start_dim=1)
    return embedding


def extract_and_save_bbox(image_path, output_directory, indice, x, y, w, h):
    image = Image.open(image_path).convert("RGB")
    # Calcola il bounding box (left, top, right, bottom)
    left = x
    top = y
    right = x + w
    bottom = y + h

    # Estrai il bounding box
    cropped_image = image.crop((left, top, right, bottom))

    output_path = os.path.join(output_directory, f'bounding_box{indice}.jpg')
    cropped_image.save(output_path)



def generate_coordinates(x, y, num_points=8):

    coordinates = []
    angle_step = 360 / (num_points)  # Passo angolare per equidistribuzione

    for i in range(num_points):
        angle = angle_step * i  # Angolo corrente
        angle_rad = math.radians(angle)  # Conversione in radianti

        # Calcola le nuove coordinate
        new_x = int(x + 15 * math.cos(angle_rad))
        new_y = int(y + 10 * math.sin(angle_rad))
        coordinates.append((new_x, new_y))

        # Calcola le nuove coordinate
        new_x = int(x + 30 * math.cos(angle_rad))
        new_y = int(y + 20 * math.sin(angle_rad))
        coordinates.append((new_x, new_y))

        # Calcola le nuove coordinate
        new_x = int(x + 45 * math.cos(angle_rad))
        new_y = int(y + 25 * math.sin(angle_rad))
        coordinates.append((new_x, new_y))

    return coordinates

def prediciCoordinateSuccessive(previous_image, current_image, x, y, w, h):
  #Calcolo embedding bounding box immagine precedente
  extract_and_save_bbox(previous_image, tmp_directory, 0, x, y, w, h)
  embedding_0= extract_embedding(os.path.join(tmp_directory, "bounding_box0.jpg"))

  coordinate = generate_coordinates(x, y)
  maxSimilarity=-1
  i= 1
  #Scelta del bounding box candidato che massimizza la similarità del coseno
  for (x1, y1) in coordinate:
    extract_and_save_bbox(current_image, tmp_directory, i, x1, y1, w, h)
    embedding_1= extract_embedding(os.path.join(tmp_directory, f'bounding_box{i}.jpg'))
    similarity = cosine_similarity(embedding_0, embedding_1)
    if similarity> maxSimilarity:
      maxSimilarity = similarity
      x_ris, y_ris= x1, y1

    i=i+1
  return x_ris, y_ris
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 141MB/s]

# %% [markdown]
# ### PREDIZIONE VIDEO DI TEST

# %%
from ultralytics import YOLO

import cv2
import json
import numpy as np
import math

#Calcolo della distanza tra una posizione e la media delle posizioni precedenti.
def calculate_distance(center_x, center_y, last_predictions):
    sum_x = 0
    sum_y = 0
    for x, y in last_predictions:
        sum_x += x
        sum_y += y
    avg_x = sum_x / len(last_predictions)
    avg_y = sum_y / len(last_predictions)
    distance = math.sqrt((center_x - avg_x) ** 2 + (3*(center_y - avg_y)) ** 2)
    return distance



# Caricamento il modello YOLOv8 pre-addestrato
model = YOLO('best.pt')
video_path = ["ID-5.avi", "ID-6.avi"]

tmp_directory= 'tmp/'
os.makedirs(tmp_directory, exist_ok=True)


raccoltaRisultato = []

for j in range(len(video_path)):

  cap = cv2.VideoCapture(video_path[j])

  if not cap.isOpened():
      print("Errore nell'apertura del video!")
      exit()

  risultato = {}
  i = 0
  x_curr=-1
  y_curr=-1
  max_it=20

  last_predictions=[]

  # Lettura del video frame per frame
  while True:
      ret, frame = cap.read()
      if not ret:  # Se non ci sono più frame, esci
          break
      cv2.imwrite("/content/tmp/immagine_corrente.jpg", frame)

      key = f"{i:05}"
      i += 1
      results = model.predict(source=frame, conf=0.69, save=False, save_txt=False)



      palla_trovata = False

      min_distance=2000
      for result in results[0].boxes:
          class_index = result[0].cls.item()  # Indice della classe
          if class_index == 0:  # Classe corrispondente alla palla
              max_it=20
              palla_trovata = True
              x1, y1, x2, y2 = result[0].xyxy[0]  # Coordinate del bounding box
              center_x = float((x1 + x2) / 2)
              center_y = float((y1 + y2) / 2)


              if last_predictions!=[]:
                distance = calculate_distance(center_x, center_y, last_predictions)
                if distance < min_distance:
                  min_distance = distance
                  x_curr, y_curr= center_x, center_y
              else:
                x_curr, y_curr= center_x, center_y

      if not palla_trovata and x_curr!=-1 and max_it>0:
          x_p, y_p= prediciCoordinateSuccessive("tmp/immagine_precedente.jpg", "tmp/immagine_corrente.jpg",x_curr, y_curr, 40, 40)
          if x_p>0 and x_p<=1920 and y_p>0 and y_p<=1080:
            max_it-=1
            x_curr, y_curr= x_p, y_p
          else:
            x_curr, y_curr= -1, -1
      elif not palla_trovata:
        x_curr, y_curr= -1, -1

      risultato[key] = {"x": round(x_curr, 6), "y": round(y_curr, 6)}

      if x_curr==-1 and len(last_predictions)>0:
        last_predictions.pop(0)
      else:
        last_predictions.append((x_curr, y_curr))
        if len(last_predictions)>10:
          last_predictions.pop(0)
      cv2.imwrite("/content/tmp/immagine_precedente.jpg", frame)


      # Esci premendo 'q'
      if cv2.waitKey(1) & 0xFF == ord('q'):
          break

  tmp = {}
  tmp.update(risultato)
  raccoltaRisultato.append(tmp)

  cap.release()
  cv2.destroyAllWindows()
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Speed: 4.4ms preprocess, 21.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.2ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 6.6ms preprocess, 21.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.0ms preprocess, 21.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.3ms
# Speed: 8.2ms preprocess, 21.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.5ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.1ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.5ms
# Speed: 4.6ms preprocess, 26.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.4ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.5ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 6.3ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.0ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.1ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 6.4ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 4.9ms preprocess, 22.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 8.4ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.6ms
# Speed: 6.3ms preprocess, 24.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.6ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 8.2ms preprocess, 22.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.9ms
# Speed: 4.2ms preprocess, 22.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 6.1ms preprocess, 22.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 8.1ms preprocess, 25.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.7ms
# Speed: 4.7ms preprocess, 23.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 5.5ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 5.1ms preprocess, 24.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.4ms
# Speed: 4.6ms preprocess, 24.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.6ms
# Speed: 4.6ms preprocess, 23.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.6ms
# Speed: 5.1ms preprocess, 23.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.5ms
# Speed: 5.1ms preprocess, 23.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.6ms
# Speed: 4.9ms preprocess, 23.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 5.2ms preprocess, 24.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 6.8ms preprocess, 24.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.9ms
# Speed: 9.4ms preprocess, 23.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 7.8ms preprocess, 24.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.9ms
# Speed: 6.7ms preprocess, 23.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.9ms
# Speed: 4.5ms preprocess, 23.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 4.5ms preprocess, 25.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.6ms
# Speed: 4.5ms preprocess, 24.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 4.7ms preprocess, 24.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 4.7ms preprocess, 24.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.2ms
# Speed: 4.2ms preprocess, 24.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 4.6ms preprocess, 24.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 4.8ms preprocess, 24.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 5.3ms preprocess, 24.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.2ms
# Speed: 4.6ms preprocess, 25.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.9ms
# Speed: 4.5ms preprocess, 24.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 4.5ms preprocess, 25.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 29.0ms
# Speed: 4.7ms preprocess, 29.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.4ms
# Speed: 6.2ms preprocess, 25.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 4.7ms preprocess, 25.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 8.4ms preprocess, 25.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.2ms
# Speed: 4.7ms preprocess, 27.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 4.5ms preprocess, 25.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 4.6ms preprocess, 25.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 4.6ms preprocess, 26.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 4.7ms preprocess, 26.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.4ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.4ms
# Speed: 8.9ms preprocess, 26.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 5.9ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.5ms
# Speed: 4.4ms preprocess, 26.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.6ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.4ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.7ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 6.1ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 4.8ms preprocess, 26.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.2ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 5.0ms preprocess, 26.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.7ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.7ms
# Speed: 4.5ms preprocess, 27.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 28.0ms
# Speed: 5.6ms preprocess, 28.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 4.5ms preprocess, 26.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 4.7ms preprocess, 26.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.6ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.9ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.6ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.1ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.1ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.4ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 6.1ms preprocess, 26.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 6.0ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.2ms
# Speed: 4.8ms preprocess, 27.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.8ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.3ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 6.2ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.8ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 6.8ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 8.7ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.6ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.8ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.3ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 5.2ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.7ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 5.3ms preprocess, 26.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 5.2ms preprocess, 26.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 7.3ms preprocess, 26.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 5.0ms preprocess, 26.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.1ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.6ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.3ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.8ms
# Speed: 4.5ms preprocess, 25.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.2ms
# Speed: 4.5ms preprocess, 25.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.9ms
# Speed: 5.1ms preprocess, 24.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.8ms
# Speed: 5.0ms preprocess, 24.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 5.3ms preprocess, 23.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 4.3ms preprocess, 23.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 6.3ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.5ms preprocess, 22.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.5ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.1ms
# Speed: 4.4ms preprocess, 23.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.5ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 6.7ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.7ms preprocess, 22.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 4.4ms preprocess, 23.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.1ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.3ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.6ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.6ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.5ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.9ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.3ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 8.7ms preprocess, 22.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.3ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.7ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.4ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 4.8ms preprocess, 21.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.7ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.5ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.4ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.2ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.7ms preprocess, 20.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 6.0ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 8.8ms preprocess, 20.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 4.7ms preprocess, 20.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 5.4ms preprocess, 20.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 7.2ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 6.2ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 5.3ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 4.8ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 5.1ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 5.3ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 6.3ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 4.8ms preprocess, 20.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 5.9ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.5ms
# Speed: 5.5ms preprocess, 20.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 5.8ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 5.1ms preprocess, 20.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 4.4ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 4.5ms preprocess, 20.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 9.0ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.4ms
# Speed: 4.6ms preprocess, 20.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 4.5ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 4.4ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.3ms
# Speed: 5.1ms preprocess, 20.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 4.2ms preprocess, 20.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.2ms
# Speed: 5.1ms preprocess, 20.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.1ms
# Speed: 5.1ms preprocess, 20.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.7ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.4ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 8.1ms preprocess, 19.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.6ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.7ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 6.1ms preprocess, 19.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.1ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 4.9ms preprocess, 19.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.7ms preprocess, 20.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 7.1ms preprocess, 20.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.6ms
# Speed: 5.9ms preprocess, 20.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.8ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.4ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 4.3ms preprocess, 19.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.3ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 4.5ms preprocess, 19.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.2ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 19.9ms
# Speed: 5.5ms preprocess, 19.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.6ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.2ms preprocess, 20.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 5.2ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.3ms preprocess, 20.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.1ms
# Speed: 5.5ms preprocess, 20.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.1ms
# Speed: 4.3ms preprocess, 20.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.0ms
# Speed: 4.6ms preprocess, 20.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.2ms
# Speed: 4.7ms preprocess, 20.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.4ms
# Speed: 7.1ms preprocess, 21.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 6.4ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.3ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 6.2ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.8ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 5.0ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.8ms
# Speed: 5.2ms preprocess, 21.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.9ms
# Speed: 5.4ms preprocess, 21.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 5.4ms preprocess, 21.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.1ms
# Speed: 5.3ms preprocess, 21.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.4ms
# Speed: 5.5ms preprocess, 21.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.2ms preprocess, 21.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 4.4ms preprocess, 20.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 5.2ms preprocess, 20.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.1ms
# Speed: 7.8ms preprocess, 21.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.2ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 5.8ms preprocess, 21.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.7ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 6.3ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.8ms preprocess, 21.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.7ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.4ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 4.7ms preprocess, 20.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 6.0ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 5.8ms preprocess, 20.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.4ms preprocess, 21.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.4ms preprocess, 21.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.7ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.1ms
# Speed: 6.1ms preprocess, 21.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 7.8ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.4ms
# Speed: 7.2ms preprocess, 21.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.9ms preprocess, 21.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.1ms
# Speed: 4.9ms preprocess, 21.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.1ms preprocess, 21.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.0ms
# Speed: 4.4ms preprocess, 21.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.6ms
# Speed: 6.1ms preprocess, 23.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.5ms
# Speed: 5.5ms preprocess, 25.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.1ms
# Speed: 5.3ms preprocess, 23.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 5.4ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 5.5ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 4.8ms preprocess, 23.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.8ms
# Speed: 5.4ms preprocess, 23.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 4.9ms preprocess, 23.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.5ms
# Speed: 5.4ms preprocess, 25.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 6.7ms preprocess, 25.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 4.6ms preprocess, 25.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.8ms
# Speed: 4.6ms preprocess, 24.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 4.7ms preprocess, 24.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.2ms
# Speed: 4.6ms preprocess, 24.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.2ms
# Speed: 4.8ms preprocess, 24.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.2ms
# Speed: 4.5ms preprocess, 24.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.2ms
# Speed: 4.4ms preprocess, 25.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.2ms
# Speed: 4.6ms preprocess, 26.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.9ms
# Speed: 4.5ms preprocess, 24.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.5ms
# Speed: 4.6ms preprocess, 24.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.9ms
# Speed: 7.7ms preprocess, 24.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.7ms
# Speed: 4.6ms preprocess, 24.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.4ms
# Speed: 6.3ms preprocess, 26.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.4ms
# Speed: 4.5ms preprocess, 25.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 6.5ms preprocess, 25.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 4.6ms preprocess, 25.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 4.6ms preprocess, 25.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 4.6ms preprocess, 25.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.7ms
# Speed: 5.0ms preprocess, 25.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.2ms
# Speed: 6.6ms preprocess, 26.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.6ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 5.2ms preprocess, 26.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.4ms preprocess, 26.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.4ms
# Speed: 7.4ms preprocess, 26.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.3ms
# Speed: 4.5ms preprocess, 26.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.8ms
# Speed: 7.2ms preprocess, 26.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.9ms
# Speed: 4.5ms preprocess, 26.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.6ms preprocess, 27.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.7ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.6ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.6ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 27.1ms
# Speed: 4.4ms preprocess, 27.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.6ms
# Speed: 5.6ms preprocess, 26.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.7ms preprocess, 26.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.7ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.3ms preprocess, 26.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.9ms
# Speed: 4.6ms preprocess, 26.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 30.0ms
# Speed: 4.5ms preprocess, 30.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.0ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 4.4ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.4ms preprocess, 26.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 5.3ms preprocess, 26.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.7ms
# Speed: 6.5ms preprocess, 26.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.1ms
# Speed: 4.8ms preprocess, 26.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 4.7ms preprocess, 26.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.9ms
# Speed: 5.7ms preprocess, 25.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 5.0ms preprocess, 26.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 4.7ms preprocess, 26.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 6.2ms preprocess, 26.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 6.9ms preprocess, 26.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 4.6ms preprocess, 26.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 5.4ms preprocess, 26.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 5.6ms preprocess, 26.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 5.2ms preprocess, 26.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 26.0ms
# Speed: 5.0ms preprocess, 26.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.1ms
# Speed: 5.0ms preprocess, 25.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.8ms
# Speed: 4.5ms preprocess, 23.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 5.3ms preprocess, 23.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 5.2ms preprocess, 23.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 5.4ms preprocess, 23.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.9ms
# Speed: 4.5ms preprocess, 22.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.7ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.9ms
# Speed: 5.0ms preprocess, 22.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.4ms preprocess, 22.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.0ms
# Speed: 4.9ms preprocess, 23.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.5ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.6ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.2ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.7ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.8ms preprocess, 22.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.5ms
# Speed: 5.4ms preprocess, 22.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.9ms
# Speed: 5.7ms preprocess, 21.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 6.0ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.3ms preprocess, 22.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.9ms preprocess, 22.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 4.8ms preprocess, 22.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.7ms
# Speed: 5.4ms preprocess, 22.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 5.9ms preprocess, 22.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.0ms preprocess, 22.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 4.6ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.9ms
# Speed: 4.9ms preprocess, 21.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 4.7ms preprocess, 22.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 4.5ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.9ms
# ...
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 4.3ms preprocess, 25.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 5.2ms preprocess, 25.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.6ms
# Speed: 4.3ms preprocess, 25.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 25.0ms
# Speed: 5.1ms preprocess, 25.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.7ms
# Speed: 4.6ms preprocess, 22.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.2ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.1ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.3ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.6ms
# Speed: 5.9ms preprocess, 22.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.2ms preprocess, 22.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 4.7ms preprocess, 22.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 7.0ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.1ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.2ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.7ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.4ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.5ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.6ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.4ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.1ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.5ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.4ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.2ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 7.7ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.6ms
# Speed: 5.1ms preprocess, 23.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 6.5ms preprocess, 22.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.4ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.5ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.3ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 6.3ms preprocess, 22.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.7ms
# Speed: 4.6ms preprocess, 22.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 5.3ms preprocess, 22.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.8ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.2ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.9ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.4ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 5.5ms preprocess, 21.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.8ms
# Speed: 6.4ms preprocess, 21.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.4ms preprocess, 22.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 6.2ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.0ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 5.2ms preprocess, 21.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.0ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.8ms
# Speed: 4.7ms preprocess, 21.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.9ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.5ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.1ms
# Speed: 5.3ms preprocess, 22.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.5ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.2ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.1ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 7.4ms preprocess, 21.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 5.3ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.7ms
# Speed: 4.3ms preprocess, 21.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 5.4ms preprocess, 21.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.6ms
# Speed: 5.7ms preprocess, 21.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 4.7ms preprocess, 22.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 4.7ms preprocess, 22.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.0ms
# Speed: 5.7ms preprocess, 22.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.5ms
# Speed: 6.3ms preprocess, 22.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 5.9ms preprocess, 22.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 4.6ms preprocess, 22.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.2ms
# Speed: 5.3ms preprocess, 22.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.3ms
# Speed: 4.6ms preprocess, 21.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.1ms
# Speed: 4.6ms preprocess, 21.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.3ms
# Speed: 4.7ms preprocess, 21.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 4.8ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 6.0ms preprocess, 20.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.9ms
# Speed: 5.6ms preprocess, 20.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 4.9ms preprocess, 20.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 8.7ms preprocess, 20.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.5ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 5.0ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.3ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 5.1ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.2ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 4.7ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.4ms preprocess, 20.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 4.6ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 5.1ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 5.5ms preprocess, 20.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 4.5ms preprocess, 20.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 4.8ms preprocess, 20.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 9.1ms preprocess, 21.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 21.2ms
# Speed: 4.3ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.9ms
# Speed: 4.4ms preprocess, 23.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.3ms
# Speed: 7.4ms preprocess, 22.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.7ms
# Speed: 4.8ms preprocess, 20.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 5.0ms preprocess, 20.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 7.6ms preprocess, 20.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 20.8ms
# Speed: 4.6ms preprocess, 20.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.9ms
# Speed: 4.5ms preprocess, 22.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.7ms
# Speed: 4.6ms preprocess, 22.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.4ms
# Speed: 4.2ms preprocess, 22.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 4.5ms preprocess, 23.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.2ms
# Speed: 4.4ms preprocess, 23.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.6ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.4ms preprocess, 22.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 22.8ms
# Speed: 4.7ms preprocess, 22.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.7ms
# Speed: 4.5ms preprocess, 23.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.7ms
# Speed: 4.6ms preprocess, 23.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.7ms
# Speed: 4.6ms preprocess, 24.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.8ms
# Speed: 4.4ms preprocess, 23.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.8ms
# Speed: 4.4ms preprocess, 23.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 4.3ms preprocess, 23.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 5.5ms preprocess, 23.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.4ms
# Speed: 4.5ms preprocess, 23.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 23.3ms
# Speed: 4.5ms preprocess, 23.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.4ms
# Speed: 4.6ms preprocess, 24.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
#
# 0: 480x800 (no detections), 24.3ms
# Speed: 4.6ms preprocess, 24.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 800)
# ['00466', '00533', '00534', '00543', '02485', '02486', '02487', '02488', '02489', '02493', '02494', '02495', '02496', '02497', '02498', '02499', '02500', '02501', '02502', '02503', '02504', '02510', '02511', '02514', '02515', '02516', '02517', '02518', '02519', '02520', '02521', '02522', '02523', '02524', '02525', '02526', '02527', '02528', '02529', '02530', '02531', '02534', '02535', '02537', '02538', '02539', '02540']

# %%
import os
import re
import json
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

plt.rcParams["figure.figsize"] = (10, 8)


class TrackingEvaluator:
    def __init__(self, gt_ann_file, pred_file):
        self.gt_ann_file = gt_ann_file
        self.pred_file = pred_file
        self.gt_data_points = {}
        self.pred_points = {}
        self.frames_idx = None

    @staticmethod
    def extract_points_data(xml_content):
        root = ET.fromstring(xml_content)
        points_data = {}

        for track in root.findall(".//track"):
            for point in track.findall("points"):
                data = {
                    'frame': int(point.get("frame")),
                    'outside': int(point.get("outside")),
                    'occluded': int(point.get("occluded")),
                    'keyframe': int(point.get("keyframe")),
                    'points': tuple(map(float, point.get("points").split(","))),
                    'z_order': int(point.get("z_order")),
                }
                if data['frame'] in points_data:
                    print(f'Alert: multiple frame entries for ID {data["frame"]}')
                points_data[data['frame']] = data

        return points_data

    @staticmethod
    def _convert_key(k):
        return int(Path(k).stem)

    def load_data(self):
        # Load ground truth data
        gt_content = Path(self.gt_ann_file).read_text()
        self.gt_data_points = self.extract_points_data(gt_content)


        # Load prediction data
        pred_content = Path(self.pred_file).read_text().replace('-Infinity', '-1').replace('Infinity', '-1')
        raw_pred_points = json.loads(pred_content)

        self.pred_points = {
            self._convert_key(k): v for k, v in raw_pred_points.items() if v['x'] >= 0
        }


    def compute_frame_indices(self):
        ordered_list_pred_frame = sorted(self.pred_points.keys())
        ordered_list_gt_frame = sorted(self.gt_data_points.keys())

        print(f'GT   frames: {ordered_list_gt_frame[0]} - {ordered_list_gt_frame[-1]}')
        print(f'PRED frames: {ordered_list_pred_frame[0]} - {ordered_list_pred_frame[-1]}')

        self.frames_idx = (
            min(ordered_list_gt_frame[0], ordered_list_pred_frame[0]),
            max(ordered_list_gt_frame[-1], ordered_list_pred_frame[-1]),
        )
        print(f'Frame Index Range: {self.frames_idx}')

    @staticmethod
    def is_match(x1, y1, x2, y2, threshold=4):
        p1 = np.array((x1, y1))
        p2 = np.array((x2, y2))
        euclid_dist = np.sqrt(np.dot((p1 - p2).T, (p1 - p2)))
        return euclid_dist < threshold

    def evaluate_metrics(self):
        cnt_match = 0
        cnt_no_match = 0
        cnt_no_pred = 0
        cnt_no_frame = 0

        for i in range(self.frames_idx[0], self.frames_idx[1] + 1):
            if i not in self.gt_data_points:
                cnt_no_frame += 1
                continue
            if i not in self.pred_points:
                cnt_no_pred += 1
                continue

            p1 = self.gt_data_points[i]
            p2 = self.pred_points[i]

            if self.is_match(*p1['points'], p2['x'], p2['y']):
                cnt_match += 1
            else:
                cnt_no_match += 1

        total_frames = len(self.gt_data_points)
        print(f'Total frames: {total_frames}')
        print(f'Total predictions: {len(self.pred_points)}')
        print(f'Matches: {cnt_match} ({cnt_match / total_frames:.3f})')
        print(f'No matches: {cnt_no_match} ({cnt_no_match / total_frames:.3f})')
        print(f'No predictions: {cnt_no_pred} ({cnt_no_pred / total_frames:.3f})')
        print(f'No frame data: {cnt_no_frame} ({cnt_no_frame / (self.frames_idx[1] - self.frames_idx[0] + 1):.3f})')

    def compute_tracking_sequence(self):
        norm_width = 1920
        norm_height = 1080

        gt_seq = []
        pred_seq = []

        for i in range(min(self.gt_data_points.keys()), max(self.gt_data_points.keys()) + 1):
            if i in self.gt_data_points:
                if i not in self.pred_points:
                    pred_seq.append((0, 0))
                else:
                    p2 = self.pred_points[i]
                    pred_seq.append((p2['x'] / norm_width, p2['y'] / norm_height))

                x, y = self.gt_data_points[i]['points']
                gt_seq.append((x / norm_width, y / norm_height))

        return gt_seq, pred_seq

    def compute_mse(self):
        gt_seq, pred_seq = self.compute_tracking_sequence()
        mse = mean_squared_error(gt_seq, pred_seq)
        print(f'Mean Squared Error: {mse}')
        return mse

# %%
future_len = 5
past_erase = 18

for risultato in raccoltaRisultato:

  x_past = -1

  for i in range(len(risultato)):
    key = f"{i:05}"
    if risultato.get(key)["x"] == -1 and x_past != -1: # se la corrente è (-1,-1) e c'è qualcosa da cancellare
      erase = True
      for m in range(i+1, min(i + future_len, len(risultato))):
        tmp = f"{m:05}"
        if risultato.get(key)["x"] != -1:
          erase = False
          break

      if erase:
        for n in range(max(0, i - past_erase), i):
          tmp = f"{n:05}"
          risultato[tmp] = {"x": round(-1, 6), "y": round(-1, 6)}

    x_past = risultato[key]["x"]

# %%
with open(f"annotazione{0}.json", "w") as f:
      json.dump(raccoltaRisultato[0], f, indent=4)
with open(f"annotazione{1}.json", "w") as f:
      json.dump(raccoltaRisultato[1], f, indent=4)

# %%
gt_ann_file = 'ID-5.xml'
pred_file = 'annotazione0.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse5 = evaluator.compute_mse();
# Out:
# GT   frames: 420 - 2580
# PRED frames: 424 - 2986
# Frame Index Range: (420, 2986)
# Total frames: 346
# Total predictions: 376
# Matches: 243 (0.702)
# No matches: 91 (0.263)
# No predictions: 12 (0.035)
# No frame data: 2221 (0.865)
# Mean Squared Error: 0.01901327778898359

# %%
gt_ann_file = 'ID-6.xml'
pred_file = 'annotazione1.json'

evaluator = TrackingEvaluator(gt_ann_file, pred_file)
evaluator.load_data()
evaluator.compute_frame_indices()
evaluator.evaluate_metrics()
mse6 = evaluator.compute_mse();
# Out:
# GT   frames: 417 - 2495
# PRED frames: 418 - 2495
# Frame Index Range: (417, 2495)
# Total frames: 263
# Total predictions: 265
# Matches: 227 (0.863)
# No matches: 34 (0.129)
# No predictions: 2 (0.008)
# No frame data: 1816 (0.873)
# Mean Squared Error: 0.00509335086108523

# %%
print((mse5+mse6)/2)
# Out:
# 0.01205331432503441
